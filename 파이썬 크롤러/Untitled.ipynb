# %%
import pandas as pd
import pandas_datareader as pdr
import time
import os
from random import *
os.chdir('C:\\Users\\55754\\Documents\\야후파이낸스 재무재표')
ticker=pd.read_csv('data/ticker/ticker.csv', index_col=0, header=0)
symbol=ticker['symbol']
for v, i in enumerate(symbol):
    try :
        f=pdr.DataReader(i,'yahoo')
        f.to_csv("data/pyprice/%s_price.csv" %i)
        time.sleep(randint(1,3)*randint(2,5))
    except :
        time.sleep(120)
        print("error in %s" %i)
    finally :
        print("=====%d/%d=====" %(v+1,len(symbol)), end='\r')
# Out:
# error in AAXN===
# error in ACAM====
# error in AIMT====
# error in AKCA====
# error in AMAG=====
# error in AMRH=====
# error in ARYB=====
# error in AXGT=====
# error in BMCH=====
# error in BSTC=====
# error in CCCL=====
# error in CETV=====
# error in CFBI=====
# error in CFFA=====
# error in CFFAU====
# error in CPAA=====
# error in DNKN=====
# error in DPHC=====
# error in DRAD=====
# error in EDNT=====
# error in EIDX=====
# error in FMCI=====
# error in FMCIU====
# error in FRAN6=====
# error in FTAC6=====
# error in FTACU=====
# error in GARS6=====
# error in GEC36=====
# error in GHIV6=====
# error in GLIBA=====
# error in GMHI6=====
# error in GPOR6=====
# error in GRIF6=====
# error in HCAC6=====
# error in HCACU=====
# error in HCCH6=====
# error in HCCHU=====
# error in HCCO6=====
# error in HDS36=====
# error in HEBT6=====
# error in HYAC6=====
# error in IMMU6=====
# error in INSU6=====
# error in INSUU=====
# error in KBLM6=====
# error in KBLMU=====
# error in KTOV6=====
# error in LCA36=====
# error in LCAHU=====
# error in LFAC6=====
# error in LFACU=====
# error in LSAC6=====
# error in LVGO6=====
# error in MGEN6=====
# error in MNCL6=====
# error in MNCLU=====
# error in MYL36=====
# error in MYOK6=====
# error in MYOS6=====
# error in NFIN6=====
# error in NGHC6=====
# error in NGHCN=====
# error in NTRP6=====
# error in NVUS6=====
# error in NWGI6=====
# error in OPESU=====
# error in ORSN6=====
# error in PDLI6=====
# error in PECK6=====
# error in PEIX6=====
# error in PIH36=====
# error in PIHPP=====
# error in PRCP6=====
# error in PRSC6=====
# error in PRVL6=====
# error in PTAC6=====
# error in PTI36=====
# error in RADI6=====
# error in REXN6=====
# error in RTRX6=====
# error in SAMA6=====
# error in SAMAU=====
# error in SAQN6=====
# error in SBPH6=====
# error in SMMC6=====
# error in SNBP6=====
# error in TOTA6=====
# error in TOTAU=====
# error in TZAC6=====
# error in WINS6=====
# error in WMGI6=====
# error in WRTC6=====
# error in YIN36=====
# error in ADSW6=====
# error in ACH36=====
# error in ARA36=====
# error in BMRG6=====
# error in BTE36=====
# error in BCE36=====
# error in BITA6=====
# error in CBL36=====
# error in CXO36=====
# error in CCR36=====
# error in DMYT6=====
# error in FCAU6=====
# error in FIT36=====
# error in FEAC6=====
# error in FVAC6=====
# error in FBM36=====
# error in RESI6=====
# error in GPS36=====
# error in GRAM6=====
# error in GSH36=====
# error in HTZ36=====
# error in HUD36=====
# error in HCFT6=====
# error in IRET6=====
# error in JCAP6=====
# error in KCAC6=====
# error in LGC36=====
# error in LN836=====
# error in LOAK6=====
# error in MNK36=====
# error in MANU6=====
# error in MFAC6=====
# error in MR836=====
# error in OAC36=====
# error in ONDK6=====
# error in PACD6=====
# error in PE836=====
# error in PIC36=====
# error in RMG36=====
# error in RST36=====
# error in SRG36=====
# error in IPOB6=====
# error in IPOC6=====
# error in SPAQ6=====
# error in TCO36=====
# error in TIF36=====
# error in TSU36=====
# error in TRNE6=====
# error in TRWH6=====
# error in WPX36=====
# =====4836/4836=====
